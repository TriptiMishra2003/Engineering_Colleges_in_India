# %%
import numpy as nm 
import matplotlib.pyplot as mtp 
import pandas as pd
dataset =pd.read_csv('engineering colleges in India.csv')

# %%
dataset
# Out:
#                                            College Name Genders Accepted  \
# 0            National Institute of Technology Rourkela             Co-Ed
# 1     Visvesvaraya National Institute of Technology ...            Co-Ed
# 2                Netaji Subhas University of Technology            Co-Ed
# 3                         Birla Institute of Technology            Co-Ed
# 4     International Institute of Information Technology            Co-Ed
# ...                                                 ...              ...
# 5441                        BES Institute of Technology            Co-Ed
# 5442                        Radical Polytechnic College            Co-Ed
# 5443       Trimurti Institute of Technology Polytechnic            Co-Ed
# 5444  RV Parankar College of Engineering and Technology            Co-Ed
# 5445                       Centre for Design Excellence            Co-Ed
#
#      Campus Size Total Student Enrollments Total Faculty Established Year  \
# ...

# %%
dataset.head(5)
# Out:
#                                         College Name Genders Accepted  \
# 0         National Institute of Technology Rourkela             Co-Ed
# 1  Visvesvaraya National Institute of Technology ...            Co-Ed
# 2             Netaji Subhas University of Technology            Co-Ed
# 3                      Birla Institute of Technology            Co-Ed
# 4  International Institute of Information Technology            Co-Ed
#
#   Campus Size Total Student Enrollments Total Faculty Established Year Rating  \
# 0   647 Acres                      4811           329             2007   3.12
# 1   215 Acres                      1071           192             2007    NaN
# 2   145 Acres                      3759           101             2018    NaN
# 3   980 Acres                      4506           284             1955    NaN
# 4    66 Acres                      1721            85             2001   3.05
#
#   University                                            Courses  \
# ...

# %%
dataset.tail(5)
# Out:
#                                            College Name Genders Accepted  \
# 5441                        BES Institute of Technology            Co-Ed
# 5442                        Radical Polytechnic College            Co-Ed
# 5443       Trimurti Institute of Technology Polytechnic            Co-Ed
# 5444  RV Parankar College of Engineering and Technology            Co-Ed
# 5445                       Centre for Design Excellence            Co-Ed
#
#      Campus Size Total Student Enrollments Total Faculty Established Year  \
# 5441     4 Acres                       NaN            31             2003
# 5442         NaN                       NaN           NaN             2013
# 5443         NaN                        22            55             2009
# 5444         NaN                        38            10             2015
# 5445         NaN                       NaN            20              NaN
#
#      Rating                                         University  \
# ...

# %%
dataset.shape
# Out:
# (5446, 15)

# %%
dataset.size
# Out:
# 81690

# %%
dataset.columns
# Out:
# Index(['College Name', 'Genders Accepted', 'Campus Size',
#        'Total Student Enrollments', 'Total Faculty', 'Established Year',
#        'Rating', 'University', 'Courses', 'Facilities', 'City', 'State',
#        'Country', 'College Type', 'Average Fees'],
#       dtype='object')

# %%
dataset.dtypes
# Out:
# College Name                 object
# Genders Accepted             object
# Campus Size                  object
# Total Student Enrollments    object
# Total Faculty                object
# Established Year             object
# Rating                       object
# University                   object
# Courses                      object
# Facilities                   object
# City                         object
# State                        object
# Country                      object
# College Type                 object
# Average Fees                 object
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5446 entries, 0 to 5445
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   College Name               5446 non-null   object
#  1   Genders Accepted           5428 non-null   object
#  2   Campus Size                2695 non-null   object
#  3   Total Student Enrollments  4443 non-null   object
#  4   Total Faculty              5285 non-null   object
#  5   Established Year           5345 non-null   object
#  6   Rating                     333 non-null    object
#  7   University                 3510 non-null   object
#  8   Courses                    5446 non-null   object
#  9   Facilities                 5434 non-null   object
#  10  City                       5446 non-null   object
#  11  State                      5446 non-null   object
#  12  Country                    5446 non-null   object
# ...

# %%
dataset[dataset.duplicated()]
# Out:
#       College Name  Genders Accepted  Campus Size  Total Student Enrollments  \
# 1735  College Name  Genders Accepted  Campus Size  Total Student Enrollments
# 3622  College Name  Genders Accepted  Campus Size  Total Student Enrollments
# 4277  College Name  Genders Accepted  Campus Size  Total Student Enrollments
# 4494  College Name  Genders Accepted  Campus Size  Total Student Enrollments
# 4790  College Name  Genders Accepted  Campus Size  Total Student Enrollments
#
#       Total Faculty  Established Year  Rating  University  Courses  \
# 1735  Total Faculty  Established Year  Rating  University  Courses
# 3622  Total Faculty  Established Year  Rating  University  Courses
# 4277  Total Faculty  Established Year  Rating  University  Courses
# 4494  Total Faculty  Established Year  Rating  University  Courses
# 4790  Total Faculty  Established Year  Rating  University  Courses
#
#       Facilities  City  State  Country  College Type  Average Fees
# ...

# %%
dataset.drop_duplicates(keep=False ,inplace=True)

# %%
dataset[dataset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [College Name, Genders Accepted, Campus Size, Total Student Enrollments, Total Faculty, Established Year, Rating, University, Courses, Facilities, City, State, Country, College Type, Average Fees]
# Index: []

# %%
dataset.isnull()
# Out:
#       College Name  Genders Accepted  Campus Size  Total Student Enrollments  \
# 0            False             False        False                      False
# 1            False             False        False                      False
# 2            False             False        False                      False
# 3            False             False        False                      False
# 4            False             False        False                      False
# ...            ...               ...          ...                        ...
# 5441         False             False        False                       True
# 5442         False             False         True                       True
# 5443         False             False         True                      False
# 5444         False             False         True                      False
# 5445         False             False         True                       True
#
# ...

# %%
dataset.isnull().sum()
# Out:
# College Name                    0
# Genders Accepted               18
# Campus Size                  2751
# Total Student Enrollments    1003
# Total Faculty                 161
# Established Year              101
# Rating                       5113
# University                   1936
# Courses                         0
# Facilities                     12
# City                            0
# State                           0
# Country                         0
# College Type                    1
# Average Fees                    0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(dataset.isnull())
# Out:
# <AxesSubplot:>

# %%
dataset.dtypes
# Out:
# College Name                 object
# Genders Accepted             object
# Campus Size                  object
# Total Student Enrollments    object
# Total Faculty                object
# Established Year             object
# Rating                       object
# University                   object
# Courses                      object
# Facilities                   object
# City                         object
# State                        object
# Country                      object
# College Type                 object
# Average Fees                 object
# dtype: object

# %%
dataset['Date_Name']=pd.to_datetime(dataset['Established Year'])

# %%
dataset.head()
# Out:
#                                         College Name Genders Accepted  \
# 0         National Institute of Technology Rourkela             Co-Ed
# 1  Visvesvaraya National Institute of Technology ...            Co-Ed
# 2             Netaji Subhas University of Technology            Co-Ed
# 3                      Birla Institute of Technology            Co-Ed
# 4  International Institute of Information Technology            Co-Ed
#
#   Campus Size Total Student Enrollments Total Faculty Established Year Rating  \
# 0   647 Acres                      4811           329             2007   3.12
# 1   215 Acres                      1071           192             2007    NaN
# 2   145 Acres                      3759           101             2018    NaN
# 3   980 Acres                      4506           284             1955    NaN
# 4    66 Acres                      1721            85             2001   3.05
#
#   University                                            Courses  \
# ...

# %%
dataset.dtypes
# Out:
# College Name                         object
# Genders Accepted                     object
# Campus Size                          object
# Total Student Enrollments            object
# Total Faculty                        object
# Established Year                     object
# Rating                               object
# University                           object
# Courses                              object
# Facilities                           object
# City                                 object
# State                                object
# Country                              object
# College Type                         object
# Average Fees                         object
# Date_Name                    datetime64[ns]
# dtype: object

# %%
dataset[dataset['College Name'].isin(['Bennett University'])]
# Out:
#            College Name Genders Accepted Campus Size  \
# 178  Bennett University            Co-Ed    68 Acres
#
#     Total Student Enrollments Total Faculty Established Year Rating  \
# 178                      1412            64             2016    NaN
#
#     University                                            Courses  \
# 178        NaN  B.Tech Computer Science and Engineering, BA Jo...
#
#                                             Facilities           City  \
# 178  Boys Hostel, Girls Hostel, Gym, Library, Sport...  Greater Noida
#
#              State Country College Type Average Fees  Date_Name
# 178  Uttar Pradesh   India      Private    1154000.0 2016-01-01

# %%
dataset['Date_Name'].dt.year.value_counts()
# Out:
# 2008.0    683
# 2009.0    651
# 2010.0    418
# 2007.0    294
# 2001.0    246
#          ...
# 1940.0      1
# 1913.0      1
# 1942.0      1
# 1944.0      1
# 2019.0      1
# Name: Date_Name, Length: 110, dtype: int64

# %%
dataset['Date_Name'].dt.year.value_counts().plot(kind='bar',figsize=(60, 20))
mtp.xlabel("Year of Establishment",labelpad=14)
mtp.ylabel("Number of Engineering Colleges",labelpad=14)
mtp.title("Number of Engineering Colleges Established per Year",y=1);

# %%
from IPython.display import Image

# %%
Image(filename='Enrolment-in-Engineering-Colleges_Engineering-Technology-Enrolment-of-Boys-Vs-Girls-in-India-1024x659.jpg', width=1200, height=300)

# %%
Image(filename='Enrolment-in-Engineering-Colleges_Engineering-Technology-Passed-Vs-Placed-Students-in-India-1024x589.jpg',width=1200,height=100)

# %%
dataset.groupby('State').State.count()
# Out:
# State
# Andaman and Nicobar Islands      1
# Andhra Pradesh                 386
# Arunachal Pradesh                6
# Assam                           35
# Bihar                           52
# Chandigarh                       8
# Chhattisgarh                    79
# Dadra and Nagar Haveli           1
# Delhi                           39
# Goa                             13
# Gujarat                        241
# Haryana                        263
# Himachal Pradesh                65
# Jammu and Kashmir               21
# Jharkhand                       47
# Karnataka                      339
# Kerala                         233
# Madhya Pradesh                 261
# Maharashtra                    712
# Manipur                          8
# Meghalaya                        8
# Mizoram                          5
# Nagaland                         5
# Odisha                         190
# Puducherry                      24
# Punjab                         227
# ...

# %%
sns.countplot(dataset['State'])
# Out:
# C:\Users\Tripti Mishra\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='State', ylabel='count'>

# %%
dataset.groupby('College Type').State.count()
# Out:
# College Type
# Private              4474
# Public/Government     965
# Name: State, dtype: int64

# %%
sns.countplot(dataset['College Type'])
# Out:
# C:\Users\Tripti Mishra\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='College Type', ylabel='count'>

# %%
dataset['Established Year']=dataset['Date_Name'].dt.year

# %%
dataset
# Out:
#                                            College Name Genders Accepted  \
# 0            National Institute of Technology Rourkela             Co-Ed
# 1     Visvesvaraya National Institute of Technology ...            Co-Ed
# 2                Netaji Subhas University of Technology            Co-Ed
# 3                         Birla Institute of Technology            Co-Ed
# 4     International Institute of Information Technology            Co-Ed
# ...                                                 ...              ...
# 5441                        BES Institute of Technology            Co-Ed
# 5442                        Radical Polytechnic College            Co-Ed
# 5443       Trimurti Institute of Technology Polytechnic            Co-Ed
# 5444  RV Parankar College of Engineering and Technology            Co-Ed
# 5445                       Centre for Design Excellence            Co-Ed
#
#      Campus Size Total Student Enrollments Total Faculty  Established Year  \
# ...

# %%
len(dataset[(dataset['Established Year']==2010)])
# Out:
# 418

# %%
dataset[(dataset['College Type']=='Private') & (dataset['Established Year']==2010)]
# Out:
#                                      College Name Genders Accepted  \
# 43                                 VIT University            Co-Ed
# 194    Alliance College of Engineering and Design            Co-Ed
# 247                           Chitkara University            Co-Ed
# 261                  Babu Banarasi Das University            Co-Ed
# 281               Chennai Institute of Technology            Co-Ed
# ...                                           ...              ...
# 5402                   SVA College of Polytechnic            Co-Ed
# 5404                    Thaai Polytechnic College            Co-Ed
# 5415                       Yaduvanshi Polytechnic            Co-Ed
# 5417                             YSPS Polytechnic            Co-Ed
# 5418  Late Babasaheb Phadtare Polytechnic College            Co-Ed
#
#      Campus Size Total Student Enrollments Total Faculty  Established Year  \
# 43     177 Acres                      7763           381            2010.0
# ...

# %%
len(dataset[(dataset['College Type']=='Private') & (dataset['Established Year']==2010)])
# Out:
# 380

# %%
dataset[(dataset['College Type']=='Public/Government') & (dataset['Established Year']==2010)]
# Out:
#                                            College Name Genders Accepted  \
# 22              National Institute of Technology Delhi             Co-Ed
# 86            National Institute of Technology Manipur             Co-Ed
# 111               National Institute of Technology Goa             Co-Ed
# 176         National Institute of Technology Meghalaya             Co-Ed
# 177   National Institute of Technology Arunachal Pra...            Co-Ed
# 202          National Institute of Technology Nagaland             Co-Ed
# 224           National Institute of Technology Mizoram             Co-Ed
# 229            National Institute of Technology Sikkim             Co-Ed
# 412                        JNTUH College of Engineering            Co-Ed
# 449                         Rajkiya Engineering College            Co-Ed
# 483                         Rajkiya Engineering College            Co-Ed
# 569                         Rajkiya Engineering College            Co-Ed
# ...

# %%
len(dataset[(dataset['College Type']=='Public/Government') & (dataset['Established Year']==2010)])
# Out:
# 38

# %%
ad=[380,38]
ad1=['Public','Private/Government']
mtp.pie(ad,labels=ad1,autopct='%2.1f%%' )
mtp.show()

# %%
dataset[(dataset['College Type']=='Private') & (dataset['Established Year']==1990)]
# Out:
#                                            College Name Genders Accepted  \
# 734           Bharati Vidyapeeth College of Engineering            Co-Ed
# 753                       SVPM's College of Engineering            Co-Ed
# 810                Priyadarshini College of Engineering            Co-Ed
# 997   Padmabhushan Vasantdada Patil Pratishthan's Co...            Co-Ed
# 1070            Amrita Institute of Computer Technology            Co-Ed
# 1590                               Al Kabir Polytechnic            Co-Ed
# 2435                        ACME College of Engineering            Co-Ed
# 2475         Priyadarshani College of Computer Sciences            Co-Ed
# 4278                Subhash Kool College of Engineering            Co-Ed
# 4333     Ganesh Institute of Engineering and Technology            Co-Ed
# 4434                       Pimpri Chinchwad Polytechnic            Co-Ed
# 5141                        Late Vasantdada Polytechnic            Co-Ed
#
# ...

# %%
len(dataset[(dataset['College Type']=='Private') & (dataset['Established Year']==1990)])
# Out:
# 12

# %%
dataset[(dataset['College Type']=='Public/Government') & (dataset['Established Year']==1990)]
# Out:
#                                            College Name Genders Accepted  \
# 467   Thanthai Periyar Government Institute of Techn...            Co-Ed
# 871   Kavayitri Bahinabai Chaudhari North Maharashtr...            Co-Ed
# 879                   Manonmaniam Sundaranar University            Co-Ed
# 1247                                 Contai Polytechnic            Co-Ed
# 1807                              Indo German Tool Room            Co-Ed
# 2086                             Government Polytechnic            Co-Ed
# 2452         School of Energy and Environmental Studies            Co-Ed
# 2912             Government Women's Polytechnic College           Female
# 3714                     Government Polytechnic College            Co-Ed
# 4039                             Government Polytechnic            Co-Ed
# 4130                             Government Polytechnic            Co-Ed
# 4183                             Government Polytechnic            Co-Ed
# ...

# %%
len(dataset[(dataset['College Type']=='Public/Government') & (dataset['Established Year']==1990)])
# Out:
# 14

# %%
ad=[12,14]
ad1=['Public','Private/Government']
mtp.pie(ad,labels=ad1,autopct='%2.1f%%' )
mtp.show()

# %%
dataset['Rating'].nunique()
# Out:
# 109

# %%
dataset_new=dataset.dropna()

# %%
dataset_new
# Out:
#                                        College Name Genders Accepted  \
# 5                        BMS College of Engineering            Co-Ed
# 32               Thiagarajar College of Engineering            Co-Ed
# 55           Dayananda Sagar College of Engineering            Co-Ed
# 60       Chaitanya Bharathi Institute of Technology            Co-Ed
# 73                   Sinhgad College of Engineering            Co-Ed
# ...                                             ...              ...
# 1759  Vivekanandha College of Engineering for Women           Female
# 1786                 EGS Pillay Engineering College            Co-Ed
# 1887                   Mahendra Engineering College            Co-Ed
# 2718                  School of Management Sciences            Co-Ed
# 2821       PA College of Engineering and Technology            Co-Ed
#
#      Campus Size Total Student Enrollments Total Faculty  Established Year  \
# ...

# %%
dataset_new[dataset_new['Courses'].str.contains('BE Civil Engineering')]
# Out:
#                                     College Name Genders Accepted Campus Size  \
# 5                     BMS College of Engineering            Co-Ed    15 Acres
# 32            Thiagarajar College of Engineering            Co-Ed   143 Acres
# 55        Dayananda Sagar College of Engineering            Co-Ed    29 Acres
# 60    Chaitanya Bharathi Institute of Technology            Co-Ed    51 Acres
# 73                Sinhgad College of Engineering            Co-Ed     5 Acres
# ...                                          ...              ...         ...
# 1615                Builders Engineering College            Co-Ed   200 Acres
# 1714             SB Patil College of Engineering            Co-Ed    44 Acres
# 1786              EGS Pillay Engineering College            Co-Ed    37 Acres
# 1887                Mahendra Engineering College            Co-Ed   130 Acres
# 2821    PA College of Engineering and Technology            Co-Ed    50 Acres
#
# ...

# %%
dataset[(dataset['College Type']=='Private') & (dataset['State'].str.contains('Delhi'))]
# Out:
#                                            College Name Genders Accepted  \
# 49                                        Jamia Hamdard            Co-Ed
# 110            Maharaja Agrasen Institute of Technology            Co-Ed
# 181         Bharati Vidyapeeth's College of Engineering            Co-Ed
# 220          Amity School of Engineering and Technology            Co-Ed
# 242           Maharaja Surajmal Institute of Technology            Co-Ed
# 366           Guru Tegh Bahadur Institute of Technology            Co-Ed
# 381   Dr Akhilesh Das Gupta Institute of Technology ...            Co-Ed
# 503           Bhagwan Parshuram Institute of Technology            Co-Ed
# 524            Guru Teg Bahadur Institute of Technology            Co-Ed
# 640          HMR Institute of Technology and Management            Co-Ed
# 690                     TERI School of Advanced Studies            Co-Ed
# 798   National Institute of Aeronautical Engineering...            Co-Ed
# ...

# %%
dataset[(dataset['College Type']=='Public/Government') & (dataset['State'].str.contains('Delhi'))]
# Out:
#                                            College Name Genders Accepted  \
# 2                Netaji Subhas University of Technology            Co-Ed
# 12     Indraprastha Institute of Information Technology            Co-Ed
# 22              National Institute of Technology Delhi             Co-Ed
# 56                          Jawaharlal Nehru University            Co-Ed
# 160   Indira Gandhi Delhi Technical University for W...           Female
# 197              Indira Gandhi National Open University            Co-Ed
# 270          School of Planning and Architecture Delhi             Co-Ed
# 271              GB Pant Government Engineering College            Co-Ed
# 319              Indian Agricultural Research Institute            Co-Ed
# 414                    Ambedkar Institute of Technology            Co-Ed
# 427   Ambedkar Institute of Advanced Communication T...            Co-Ed
# 454                      Indraprastha College for Women           Female
# ...

# %%
dataset[(dataset['College Type']=='Public/Government') & (dataset['Genders Accepted'].str.contains('Female'))& (dataset['State'].str.contains('Delhi'))]
# Out:
#                                           College Name Genders Accepted  \
# 160  Indira Gandhi Delhi Technical University for W...           Female
# 454                     Indraprastha College for Women           Female
#
#     Campus Size Total Student Enrollments Total Faculty  Established Year  \
# 160         NaN                      1915            68            2013.0
# 454    21 Acres                      3352            88            1924.0
#
#     Rating                  University  \
# 160    NaN                         NaN
# 454   3.33  University of Delhi, Delhi
#
#                                                Courses  \
# 160  B.Arch, B.Tech Computer Science and Engineerin...
# 454  BA, B.Com Hons, BA Political Science Hons, B.S...
#
#                                             Facilities       City  State  \
# 160  Girls Hostel, Library, Sports, Auditorium, Med...  New Delhi  Delhi
# 454  Girls Hostel, Gym, Library, Sports, Cafeteria,...  New Delhi  Delhi
#
# ...

# %%
dataset.dtypes
# Out:
# College Name                         object
# Genders Accepted                     object
# Campus Size                          object
# Total Student Enrollments            object
# Total Faculty                        object
# Established Year                    float64
# Rating                               object
# University                           object
# Courses                              object
# Facilities                           object
# City                                 object
# State                                object
# Country                              object
# College Type                         object
# Average Fees                         object
# Date_Name                    datetime64[ns]
# dtype: object

# %%
dataset['Data_N']=pd.to_numeric(dataset['Average Fees'])

# %%
dataset
# Out:
#                                            College Name Genders Accepted  \
# 0            National Institute of Technology Rourkela             Co-Ed
# 1     Visvesvaraya National Institute of Technology ...            Co-Ed
# 2                Netaji Subhas University of Technology            Co-Ed
# 3                         Birla Institute of Technology            Co-Ed
# 4     International Institute of Information Technology            Co-Ed
# ...                                                 ...              ...
# 5441                        BES Institute of Technology            Co-Ed
# 5442                        Radical Polytechnic College            Co-Ed
# 5443       Trimurti Institute of Technology Polytechnic            Co-Ed
# 5444  RV Parankar College of Engineering and Technology            Co-Ed
# 5445                       Centre for Design Excellence            Co-Ed
#
#      Campus Size Total Student Enrollments Total Faculty  Established Year  \
# ...

# %%
dataset.dtypes
# Out:
# College Name                         object
# Genders Accepted                     object
# Campus Size                          object
# Total Student Enrollments            object
# Total Faculty                        object
# Established Year                    float64
# Rating                               object
# University                           object
# Courses                              object
# Facilities                           object
# City                                 object
# State                                object
# Country                              object
# College Type                         object
# Average Fees                         object
# Date_Name                    datetime64[ns]
# Data_N                              float64
# dtype: object

# %%
dataset['Data_N'].mean()
# Out:
# 188601.11958904492
